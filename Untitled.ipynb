# %% [markdown]
# # Immportando libereias

# %%
import requests
from bs4 import BeautifulSoup #>>Parsear el codigo HTML

# %%
#Guardando url
url = 'https://www.pagina12.com.ar/'

# %% [markdown]
# # Haciendo la solicitud

# %%
p = requests.get(url)

# %%
#Checando el status
p.status_code
# Out:
# 200

# %%
print(p.text)
# Out:
# <!DOCTYPE html><html class="no-js"><head><meta charset="utf-8"><title>Página12 | La otra mirada</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}</script><meta property="description" name="description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="fb:pages" name="fb:pages" content="1541638399393436"><meta property="og:locale" name="og:locale" content="es_AR"><meta property="og:title" name="og:title" content="Página12 | La otra mirada"><meta property="og:site_name" name="og:site_name" content="PAGINA12"><meta property="og:type" name="og:type" content="website"><meta property="og:url" name="og:url" content="https://www.pagina12.com.ar"><meta property="og:description" name="og:description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="twitter:title" name="twitter:title" content="Página12 | La otra mirada"><meta property="twitter:description" name="twitter:description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="twitter:creator" name="twitter:creator" content="@Pagina12"><meta property="twitter:site" name="twitter:site" content="@pagina12"><meta property="article:author" name="article:author" content="Página12"><meta property="article:publisher" name="article:publisher" content="https://www.facebook.com/Pagina12ok"><meta name="share_cdn_host" content="https://www.pagina12.com.ar"><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, user-scalable=yes" /><link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css"><link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css" crossorigin><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/main.min.css?v=1.0.247" media="screen"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/print.min.css?v=1.0.247" media="print"><link rel="shortcut icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.247" type="image/x-icon"><link rel="icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.247" type="image/x-icon"><link rel="apple-touch-icon" sizes="57x57" href="https://www.pagina12.com.ar/assets/media/favicon/57x57.png?v=1.0.247"><link rel="apple-touch-icon" sizes="72x72" href="https://www.pagina12.com.ar/assets/media/favicon/72x72.png?v=1.0.247"><link rel="apple-touch-icon" sizes="114x114" href="https://www.pagina12.com.ar/assets/media/favicon/114x114.png?v=1.0.247"><link rel="apple-touch-icon" sizes="120x120" href="https://www.pagina12.com.ar/assets/media/favicon/120x120.png?v=1.0.247"><link rel="apple-touch-icon" sizes="144x144" href="https://www.pagina12.com.ar/assets/media/favicon/144x144.png?v=1.0.247"><link rel="apple-touch-icon" sizes="152x152" href="https://www.pagina12.com.ar/assets/media/favicon/152x152.png?v=1.0.247"><script>dataLayer = [];dataLayer.push({"section": "home"});dataLayer.push({"suplement": "home"});dataLayer.push({"listing": "home"});dataLayer.push({"search": "-"});dataLayer.push({"author": "-"});dataLayer.push({"id": "-"});dataLayer.push({"module": "p12_home"});dataLayer.push({"enviroment": "production"});dataLayer.push({"userLoggedIn": "0"});dataLayer.push({"userContributor": "0"});</script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-THCQP5X');</script><script type='text/javascript'>(function() {var _sf_async_config = window._sf_async_config = (window._sf_async_co ...
# "><li class="twitter"><span class="share fonticon-twitter"></span></li><li class="facebook"><span class="share fonticon-facebook"></span></li><li class="mail"><span class="share fonticon-mail"></span></li></li></ul></div><div class="pirulo-label"><div class="pirulo-label-deco"></div><a href="https://www.pagina12.com.ar/pirulo/298743">BANDERA</a></div></div><div class="pirulo-block-middle"><p>El Gobierno de la Ciudad de Buenos Aires (GCBA) iluminó ayer monumentos y fachadas de edificios públicos con los colores de la bandera de España. “En esta fecha tan importante para el pueblo español, desde la ciudad los acompañamos encendiendo las luces de nuestros íconos porteños con los colores que los representan”, señaló la ministra de Espacio Público e Higiene Pública de la Ciudad, Clara Muzzio. Al parecer, para el gobierno porteño, la llegada de Colón a América fue algo relevante para España, pero no para el continente americano. Aquí, de todos modos, se conmemora el Día del Respeto a la Diversidad Cultural. Pero ya sabemos que para algunos dirigentes diferenciarse de España genera angustia, querido rey. &nbsp;</p>
# </div><div class="pirulo-block-bottom"><div class="pirulo-social hide-for-large"><ul class="social-media big" share-data="pirulo" share-url="https://www.pagina12.com.ar/pirulo/298743" share-title="BANDERA" share-desc="El Gobierno de la Ciudad de Buenos Aires (GCBA) iluminó ayer monumentos y fachadas de edificios públicos con los colores de la bandera de España. “En esta fecha tan importante para el pueblo español, desde la ciudad los acompañamos encendiendo las l..." share-img="https://www.pagina12.com.ar/assets/media/FallBack-Logo.jpg" share-body="&lt;p&gt;El Gobierno de la Ciudad de Buenos Aires (GCBA) iluminó ayer monumentos y fachadas de edificios públicos con los colores de la bandera de España. “En esta fecha tan importante para el pueblo español, desde la ciudad los acompañamos encendiendo las luces de nuestros íconos porteños con los colores que los representan”, señaló la ministra de Espacio Público e Higiene Pública de la Ciudad, Clara Muzzio. Al parecer, para el gobierno porteño, la llegada de Colón a América fue algo relevante para España, pero no para el continente americano. Aquí, de todos modos, se conmemora el Día del Respeto a la Diversidad Cultural. Pero ya sabemos que para algunos dirigentes diferenciarse de España genera angustia, querido rey. &amp;nbsp;&lt;/p&gt;
# "><li class="twitter"><span class="share fonticon-twitter big"></span></li><li class="facebook"><span class="share fonticon-facebook big"></span></li><li class="mail"><span class="share fonticon-mail big"></span></li><li class="whatsapp hide-for-medium"><span class="share fonticon-whatsapp big"></span></li><li class="telegram hide-for-medium"><span class="share fonticon-telegram big"></span></li></ul></div></div></div></div></div></div></div></div><div class="text-center iframe-margin-top hide-for-medium"><div id="div-gpt-ad-1506537706019-0"></div></div></div><div class="wrapper"><div class="expand-horizontal-sm"><div class="layout-region region-2x2 tradicional sm-horiz"><div class="row headlines-block"><div class="headlines-block-col fixed-w left flex show-for-large"><div class="central bottom-auto ad-bg ad-bg--600"><div id="div-gpt-ad-1519672027502-0"></div></div></div><div class="headlines-block-col dynamic-w"><div class="headlines-block-row"><div class="small-12 medium-6 headline-list-mobile"> <div class="headline-card headline-2 "><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-"><div class="intrinsic-container"><img class="show-for-small-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-09/108620-jub_0.jpg?itok=ik2bJWmt" alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses."><img class="show-for-medium-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-09/108620-jub_0.jpg?itok=Qod6YUcn" alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses."><img class="show-for-large-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-09/108620-jub_0.jpg?itok=ik2bJWmt" alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses."><img class="show-for-xsmall-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-09/108620-jub_0.jpg?itok=xrHMRquO" alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses."><img class="show-for-xlarge  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-09/108620-jub_0.jpg?itok=ik2bJWmt" alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses."></div></a></div></div><div class="block-content"><div class="headline-content"><div class="article-title lg "><a href="https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-" ">El cronograma de pago a jubilados en <span class="title-separator">octubre</span><span class="title-prefix">Todas las fechas de cobro</span></a></a></div><div class="time-author-wrapper article-ta "></div></div></div></article></div></div><div class="small-12 medium-6 headline-list-mobile"> <div class="headline-card headline-2 "><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/298315-no-hay-quino-sin-alicia"><div class="intrinsic-container"><img class="show-for-small-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transpa ...
# Realizadorxs Experimentales Audiovisuales.</span></a></div></div></div></div><script>var elAudioVisual = document.getElementById('audiovisual_298418');var player=document.getElementById('audiovisuales-player');player.appendChild(elAudioVisual.childNodes[0]);window._AUDIOVISUAL_SELECTED_ = 298418;</script><div class="_element" onclick="if(window._AUDIOVISUAL_SELECTED_ === 297412){return false;}var elAudioVisual = document.getElementById('audiovisual_297412');var player=document.getElementById('audiovisuales-player');var oldElAudioVisual = document.getElementById('audiovisual_'+window._AUDIOVISUAL_SELECTED_);var jwplay=player.getElementsByClassName('jwplayer');if(jwplay.length){jwplayer(jwplay[1].id).stop();}oldElAudioVisual.appendChild(player.childNodes[0]);player.innerHTML='';player.appendChild(elAudioVisual.childNodes[0]);window._AUDIOVISUAL_SELECTED_=297412;if( window.innerWidth < 768){var yOffset = player.offsetTop;window.scrollTo(0, yOffset-20);}"><div class="audiovisuales-img"><div class="audiovisuales-img-inner"><div class="play-icon"></div><img title="Música Esencial: Cecilia Pastorino + Claudio Ceccoli" src="https://images.pagina12.com.ar/styles/focal130x98/public/2020-10/111126-09-cecilia-20pastorino-20y-20claudio-20ceccoli.png?itok=MAKPJVUh" /></div></div><div class="_text">Música Esencial: Cecilia Pastorino + Claudio Ceccoli</div><div id="audiovisual_297412" class="_embedded"><div><div class="multimedia-container-wrapper"><div class="multimedia-container marginBottom"><div class="video-embed-field-responsive-video"><iframe name="b0ce5a3edc21eef4555f790010744527" width="560" height="315" src="https://www.youtube.com/embed/-qDiBBa256k?enablejsapi=1" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen id="article-youtube-embed-297412" class="article-youtube-embed"></iframe></div></div></div><div class="_text"><a href="https://www.pagina12.com.ar/297412-musica-esencial-cecilia-pastorino-claudio-ceccoli"><span>Música Esencial: Cecilia Pastorino + Claudio <span class="title-separator">Ceccoli</span></span><span class="title-prefix">Un ciclo donde lo esencial no es invisible a los ojos: la música</span></a></div></div></div></div><div class="_element" onclick="if(window._AUDIOVISUAL_SELECTED_ === 293613){return false;}var elAudioVisual = document.getElementById('audiovisual_293613');var player=document.getElementById('audiovisuales-player');var oldElAudioVisual = document.getElementById('audiovisual_'+window._AUDIOVISUAL_SELECTED_);var jwplay=player.getElementsByClassName('jwplayer');if(jwplay.length){jwplayer(jwplay[1].id).stop();}oldElAudioVisual.appendChild(player.childNodes[0]);player.innerHTML='';player.appendChild(elAudioVisual.childNodes[0]);window._AUDIOVISUAL_SELECTED_=293613;if( window.innerWidth < 768){var yOffset = player.offsetTop;window.scrollTo(0, yOffset-20);}"><div class="audiovisuales-img"><div class="audiovisuales-img-inner"><div class="play-icon"></div><img title="Néstor Restivo: ¿Qué es china? ¿Por qué debería importarle más a les argentines?" src="https://images.pagina12.com.ar/styles/focal130x98/public/2020-09/106659-maxresdefault-0.jpg?itok=2cc4zGCH" /></div></div><div class="_text">Néstor Restivo: ¿Qué es china? ¿Por qué debería importarle más a les argentines?</div><div id="audiovisual_293613" class="_embedded"><div><div class="multimedia-container-wrapper"><div class="multimedia-container marginBottom"><div class="video-embed-field-responsive-video"><iframe name="27496389bfe8b236e4dfe87e03cf327c" width="560" height="315" src="https://www.youtube.com/embed/Mx7uWVeIwjY?enablejsapi=1" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen id="article-youtube-embed-293613" class="article-youtube-embed"></iframe></div></div></div><div class="_text"><a href="https://www.pagina12.com.ar/293613-nestor-restivo-que-es-china-por-que-deberia-importarle-mas-a"> ...
# </div></div></div><div class="_text"><a href="https://www.pagina12.com.ar/269316-los-trolls-hacen-home-office"><span>Los Trolls hacen home <span class="title-separator">office</span></span><span class="title-prefix">Fake news en tiempos de coronavirus</span></a></div></div></div></div></div></div></div></div></div></div><div class="wrapper"><div class="tema-2"><div class="layout-region tema tradicional"><div class="row headlines-block headline-block-bg"><div class="headline-block-title"><div class="title-bar"></div><span class="headline-block-bg"><a href="/suplementos/no/">EL NO</a></span></div><div class="headline-block-inner"><div class="columns small-12 medium-3"><div class="headline-card headline-1 decorated multimedia"><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/298614-crixta-van-muchos-anos-de-escuchar-siempre-el-mismo-sonido"><div class="intrinsic-container"><div class="overlay img-multimedia-overlay"></div><img class="overlay img-multimedia-overlay-icon" src="https://www.pagina12.com.ar/assets/media/assets/audio-icon.svg"><img class="show-for-small-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112233-crixta-20prensa.jpg?itok=-Mch-xTv" alt="No es casualidad que con sus shows vía streaming llamaran la atención fuera del país: su sonido y mensaje son universales."><img class="show-for-medium-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112233-crixta-20prensa.jpg?itok=PPFBURx7" alt="No es casualidad que con sus shows vía streaming llamaran la atención fuera del país: su sonido y mensaje son universales."><img class="show-for-large-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112233-crixta-20prensa.jpg?itok=-Mch-xTv" alt="No es casualidad que con sus shows vía streaming llamaran la atención fuera del país: su sonido y mensaje son universales."><img class="show-for-xsmall-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/112233-crixta-20prensa.jpg?itok=Jino-tMN" alt="No es casualidad que con sus shows vía streaming llamaran la atención fuera del país: su sonido y mensaje son universales."><img class="show-for-xlarge  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112233-crixta-20prensa.jpg?itok=-Mch-xTv" alt="No es casualidad que con sus shows vía streaming llamaran la atención fuera del país: su sonido y mensaje son universales."></div></a></div></div><div class="block-content"><div class="headline-content"><div class="headline-plaque"><div class="suplement-logo suplement-no"></div></div><div class="article-title "><a href="https://www.pagina12.com.ar/298614-crixta-van-muchos-anos-de-escuchar-siempre-el-mismo-sonido" ">"Van muchos años de siempre el mismo <span class="title-separator">sonido"</span> <span class="title-prefix">Crixta sacó el disco Unity Love</span></a></a></div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a href="https://www.pagina12.com.ar/autores/1056-santiago-rial-ungaro">Santiago Rial Ungaro</a></span></div></div></div></article></div></div><div class="columns small-12 medium-3"> <div class="headline-card headline-1 "><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/298613-de-los-10-anos-de-radio-colmena-al-torneo-de-free-fire-de-cl"><div c ...
# </body></html>

# %%
#Encabexado de la respuest
p.headers
# Out:
# {'Date': 'Tue, 13 Oct 2020 03:58:42 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d3513aa514381164abcc3324b798910601602561522; expires=Thu, 12-Nov-20 03:58:42 GMT; path=/; domain=.pagina12.com.ar; HttpOnly; SameSite=Lax', 'Vary': 'Accept-Encoding', 'X-DNS-Prefetch-Control': 'off', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains', 'X-Download-Options': 'noopen', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'X-ETag': 'W/"5cd40-Sqteu3tSvwBKpEpAGAvulhBNbhY"', 'X-Backend': 'frontend', 'X-Backend-TTL': '180.000', 'X-Type': 'Dynamic URI', 'Age': '1', 'grace': '86400.000 none', 'ttl': '118.739', 'X-Instance': 'cache-front-prod-varnish-6dd6d7c6bb-xzfth', 'x-restarts': '0', 'X-Cache': 'HIT (4)', 'CF-Cache-Status': 'DYNAMIC', 'cf-request-id': '05c1b5516e00007f8040a1e200000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '5e1624c8bc6d7f80-QRO', 'Content-Encoding': 'gzip'}

# %%
#Encabezado de la solicitud
p.request.headers
# Out:
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
#Ver el metodo utilizado
p.request.method
# Out:
# 'GET'

# %%
p.request.url
# Out:
# 'https://www.pagina12.com.ar/'

# %%
s = BeautifulSoup(p.text, 'html.parser')

# %%
type(s)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ## Ver como esta estructurada la pagina

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Página12 | La otra mirada
#   </title>
#   <meta content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg" name="google-site-verification"/>
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}
#   </script>
#   <meta content="Notas focalizadas en el quehacer político de la Argentina." name="description" property="description"/>
#   <meta content="1541638399393436" name="fb:pages" property="fb:pages"/>
#   <meta content="es_AR" name="og:locale" property="og:locale"/>
#   <meta content="Página12 | La otra mirada" name="og:title" property="og:title"/>
#   <meta content="PAGINA12" name="og:site_name" property="og:site_name"/>
#   <meta content="website" name="og:type" property="og:type"/>
#   <meta content="https://www.pagina12.com.ar" name="og:url" property="og:url"/>
#   <meta content="Notas focalizadas en el quehacer político de la Argentina." name="og:description" property="og:description"/>
#   <meta content="Página12 | La otra mirada" name="twitter:title" property="twitter:title"/>
#   <meta content="Notas focalizadas en el quehacer político de la Argentina." name="twitter:description" property="twitter:description"/>
#   <meta content="@Pagina12" name="twitter:creator" property="twitter:creator"/>
#   <meta content="@pagina12" name="twitter:site" property="twitter:site"/>
#   <meta content="Página12" name="article:author" property="article:author"/>
#   <meta content="https://www.facebook.com/Pagina12ok" name="article:publisher" property="article:publisher"/>
#   <meta content="https://www.pagina12.com.ar" name="share_cdn_host"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1, user-scalable=yes" name="viewport">
#    <link href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css" rel="stylesheet" type="text/css"/>
#    <link crossorigin="" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#    <link href="https://www.pagina12.com.ar/assets/css/main.min.css?v=1.0.247" media="screen" rel="stylesheet"/>
#    <link href="https://www.pagina12.com.ar/assets/css/print.min.css?v=1.0.247" media="print" rel="stylesheet"/>
#    <link href="https://www.pagina12.com.ar/favicon.ico?v=1.0.247" rel="shortcut icon" type="image/x-icon"/>
#    <link href="https://www.pagina12.com.ar/favicon.ico?v=1.0.247" rel="icon" type="image/x-icon"/>
#    <link href="https://www.pagina12.com.ar/assets/media/favicon/57x57.png?v=1.0.247" rel="apple-touch-icon" sizes="57x57"/>
#    <link href="https://www.pagina12.com.ar/assets/media/favicon/72x72.png?v=1.0.247" rel="apple-touch-icon" sizes="72x72"/>
#    <link href="https://www.pagina12.com.ar/assets/media/favicon/114x114.png?v=1.0.247" rel="apple-touch-icon" sizes="114x114"/>
#    <link href="https://www.pagina12.com.ar/assets/media/favicon/120x120.png?v=1.0.247" rel="apple-touch-icon" sizes="120x120"/>
#    <link href="https://www.pagina12.com.ar/assets/media/favicon/144x144.png?v=1.0.247" rel="apple-touch-icon" sizes="144x144"/>
#    <link href="https://www.pagina12.com.ar/assets/media/favicon/152x152.png?v=1.0.247" rel="apple-touch-icon" sizes="152x152"/>
#    <script>
#     dataLayer = [];dataLayer.push({"section": "home"});dataLayer.push({"suplement": "home"});dataLayer.push({"listing": "home"});dataLayer.push({"search": "-"});dataLayer.push({"author": "-"});dataLayer.push({"id": "-"});dataLayer.push({"module": "p12_home"});dataLayer.push({"enviroment": "production"});dataLayer.push({"userLoggedIn": "0"});dataLayer.push({"userContributor": "0"});
#    </script>
#    <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-THCQP5X');
#    </script>
#    <script type="text/javascript">
#     (function() {var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});_sf_async_config['uid'] = 65120;_sf_async_config['domain'] = 'pagina12.com.ar';_sf_async_config['flickerControl'] = false;_sf_async_config['useCanonical'] = true;_sf_async_config['useCanonicalDomain'] = true;_sf_async_config['noCookies'] = false;_sf_async_config['topStorageDomain'] = 'top_level_domain';_sf_async_config['title'] = document.title;_sf_async_config['sections'] = 'home';_sf_async_config['authors'] = '';_sf_async_config['path'] = window.location.pathname;var _cbq = window._cbq = (window._cbq || []);_cbq.push(['_acct', 'anon']);function loadChartbeat() {var e = document.createElement('script');var n = document.getElementsByTagName('script')[0];e.type = 'text/javascript';e.async = true;e.src = '//static.chartbeat.com/js/chartbeat.js';n.parentNode.insertBefore(e, n);}loadChartbeat();})();
#    </script>
#   </meta>
#  </head>
#  <body class="bg-gray">
#   <div class="body-wrapper">
#    <div class="ads-oop">
#     <div id="div-gpt-ad-1503943435188-10">
#     </div>
#    </div>
#    <div class="ads-interstitial">
#     <div class="ad-intrstl" id="div-gpt-ad-1542048685691-0" style="display: none;">
#      <div class="closeBttn" id="div-gpt-ad-1542048685691-0_close">
#      </div>
#     </div>
#    </div>
#    <div class="ads-intersticial">
#     <div id="div-gpt-ad-1594150855223-0">
#     </div>
#    </div>
#    <div class="ads-adhesion">
#     <div id="div-gpt-ad-1594154372667-0">
#     </div>
#    </div>
#    <div class="ads-intersticial">
#     <div id="div-gpt-ad-1594152400889-0">
#     </div>
#    </div>
#    <div class="ads-adhesion">
#     <div id="div-gpt-ad-1594154141807-0">
#     </div>
#    </div>
#    <div class="header-ads banner-wrapper-top">
#     <div class="ads-horizontal-expand show-for-large">
#      <div id="div-gpt-ad-1503943435188-5">
#      </div>
#     </div>
#     <div class="ads-horizontal-expand show-for-medium-only">
#      <div id="div-gpt-ad-1503943435188-13">
#      </div>
#     </div>
#     <div class="text-center banner-wrapper not-expand-empty hide-for-medium">
#      <div id="div-gpt-ad-1503943435188-9">
#      </div>
#     </div>
#    </div>
#    <header class="header">
#     <div class="container">
#      <div class="header-top-content">
#       <div class="left-header-section">
#        <div class="logo-content">
#         <figure class="logo">
#          <a href="https://www.pagina12.com.ar">
#           <img alt="Logo Página 12" height="56" src="https://www.pagina12.com.ar/assets/media/logos/amp/logo_pagina_12_n.svg?v=1.0.247" width="270"/>
#          </a>
#         </figure>
#        </div>
#        <div class="date">
#         <span class="p12-separator--right--gray">
#          13 de octubre de 2020
#         </span>
#         <span class="p12-separator--right--gray is-uppercase">
#          <a href="/edicion-impresa">
#           Edición Impresa
#          </a>
#         </span>
#         <span class="pdf-icon-impresa">
#          <a href="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.ar" target="_top">
#           <i class="fa fa-file-pdf-o">
#           </i>
#           PDF
#          </a>
#         </span>
#        </div>
#       </div>
#       <div class="right-header-section">
#        <div class="header-subscribe-banner">
#         <strong>
#          Defendé la otra mirada
#         </strong>
#         por $300 x mes
#        </div>
#        <div class="user-content">
#         <div class="burger-access">
#          <form action="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.ar" class="login-form" method="post">
#           <input name="redirect" type="hidden" value="https://www.pagina12.com.ar"/>
#           <input name="client" type="hidden" value="hnCJNxS2l9"/>
#           <button class="button button-link is-uppercase" type="submit">
#            <span class="icon">
#             <i aria-hidden="true" class="fa fa-user">
#             </i>
#            </span>
#            <span>
#             Iniciar sesión
#            </span>
#           </button>
#          </form>
#          <a class="button button-highlight is-uppercase" href="https://www.pagina12.com.ar/socies/alta-suscripcion-plan?utm_source=pagina12&amp;utm_medium=amp_burger&amp;utm_campaign=none" target="_blank">
#           <span>
#            Hacete soci@
#           </span>
#           <span class="icon">
#            <i aria-hidden="true" class="fa fa-arrow-right">
#            </i>
#           </span>
#          </a>
#         </div>
#        </div>
#        <button class="submenu-trigger burger-icon" id="hamburger" onclick="jQuery('#mobile-menu').toggleClass('is-active');jQuery('#hamburger').toggleClass('is-active')" tabindex="2">
#         <span>
#         </span>
#         <span>
#         </span>
#         <span>
#         </span>
#        </button>
#       </div>
#      </div>
#      <div class="header-bottom-content mobile-menu" id="mobile-menu">
#       <div class="user-content-mobile mobile-menu-section">
#        <div class="user-options">
#         <form action="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.ar" method="post">
#          <input name="redirect" type="hidden" value="https://www.pagina12.com.ar"/>
#          <input name="client" type="hidden" value="hnCJNxS2l9"/>
#          <button class="button button-link login" type="submit">
#           <span>
#            Ingresar
#           </span>
#          </button>
#         </form>
#         <a class="button button-highlight membership" href="https://www.pagina12.com.ar/socies/alta-suscripcion-plan?utm_source=pagina12&amp;utm_medium=amp_burger&amp;utm_campaign=none" target="_blank">
#          <span>
#           Hacete soci@
#          </span>
#          <span class="icon">
#           <i aria-hidden="true" class="fa fa-arrow-right">
#           </i>
#          </span>
#         </a>
#        </div>
#       </div>
#       <div class="printed-block mobile-menu-section">
#        <div class="printed-menu">
#         <div class="today">
#          13 de octubre de 2020
#         </div>
#         <div class="todays-edition">
#          <span class="p12-separator--right--gray is-uppercase">
#           <a href="/edicion-impresa">
#            Edición Impresa
#           </a>
#          </span>
#          <span class="pdf-icon-impresa">
#           <a href="/?client=hnCJNxS2l9&amp;redirect=" id="NOTlogged" target="_top">
#            <i class="fa fa-file-pdf-o">
#            </i>
#            PDF
#           </a>
#          </span>
#         </div>
#         <ul class="horizontal-list main-supplements">
#         </ul>
#        </div>
#       </div>
#       <div class="left-header-section mobile-menu-section">
#        <nav class="is-display-flex" id="header-main-nav">
#         <div class="p12-dropdown" id="p12-dropdown-desktop">
#          <div class="p12-dropdown-trigger">
#           <button aria-controls="p12-dropdown-desktop" aria-haspopup="true" class="button button-text">
#            <span class="is-uppercase">
#             Secciones y Suplementos
#            </span>
#            <span class="icon is-small">
#             <svg aria-hidden="true" class="svg-inline--fa fa-angle-down fa-w-10" data-fa-i2svg="" data-icon="angle-down" data-prefix="fas" role="img" viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M143 352.3L7 216.3c-9.4-9.4-9.4-24.6 0-33.9l22.6-22.6c9.4-9.4 24.6-9.4 33.9 0l96.4 96.4 96.4-96.4c9.4-9.4 24.6-9.4 33.9 0l22.6 22.6c9.4 9.4 9.4 24.6 0 33.9l-136 136c-9.2 9.4-24.4 9.4-33.8 0z" fill="currentColor">
#              </path>
#             </svg>
#            </span>
#           </button>
#          </div>
#          <div class="p12-dropdown-pane" data-auto-focus="true" data-close-on-click="true" id="main-nav-menu">
#           <div class="p12-dropdown-content">
#            <div class="p12-dropdown-column">
#             <div class="p12-dropdown-item p12-dropdown-item--header">
#              Secciones
#             </div>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-pais">
#              El país
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/economia">
#              Economía
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/sociedad">
#              Sociedad
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">
#              Espectáculos
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/deportes">
#              Deportes
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ciencia">
#              Ciencia
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/dialogos">
#              Diálogos
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-mundo">
#              El mundo
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/edicion-impresa">
#              Edición impresa
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/universidad-diario">
#              Universidad
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ajedrez">
#              Ajedrez
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cultura">
#              Cultura
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/plastica">
#              Plástica
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/psicologia">
#              Psicología
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/hoy">
#              Hoy
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cartas-de-lectores">
#              Cartas de lectores
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/contratapa">
#              Contratapa
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/audiovisuales">
#              Audiovisuales
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/recordatorios">
#              Recordatorios
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/consumo">
#              Consumo
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/salta12">
#              Salta12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/podcasts">
#              Podcasts
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/soci@s">
#              Soci@s
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/la-ventana">
#              La ventana
#             </a>
#            </div>
#            <div class="p12-dropdown-column has-margin-on-mobile">
#             <div class="p12-dropdown-item p12-dropdown-item--header">
#              Suplementos
#             </div>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/cash">
#              Cash
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/el-enganche">
#              Enganche
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/radar">
#              Radar
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/turismo">
#              Turismo
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/radar-libros">
#              Radar Libros
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/no">
#              NO
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/soy">
#              Soy
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/las12">
#              Las12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/universidad">
#              Universidad
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/satira12">
#              Sátira12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/m2">
#              M2
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/rosario12">
#              Rosario12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/verano12">
#              Verano12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/libero">
#              Líbero
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/especiales">
#              Especiales de P12
#             </a>
#            </div>
#            <div class="social">
#             <div class="social-inner is-display-flex space-around">
#              <a href="https://www.facebook.com/Pagina12ok/" rel="me nofollow" target="_blank">
#               <i class="fa fa-facebook">
#               </i>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </nav>
#       </div>
#      </div>
#     </div>
#    </header>
#   </div>
#  </body>
# </html>
# <a href="https://twitter.com/pagina12" rel="me nofollow" target="_blank">
#  <i class="fa fa-twitter">
#  </i>
# </a>
# <a href="https://www.instagram.com/pagina12/" rel="me nofollow" target="_blank">
#  <i class="fa fa-instagram">
#  </i>
# </a>
# <a href="https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg" rel="me nofollow" target="_blank">
#  <i class="fa fa-youtube">
#  </i>
# </a>
# <a href="https://t.me/pagina12" rel="me nofollow" target="_blank">
#  <i class="fa fa-telegram">
#  </i>
# </a>
# <ul class="horizontal-list main-sections hide-on-dropdown">
#  <li class="p12-separator--right--primary">
#   <a href="https://www.pagina12.com.ar/secciones/el-pais">
#    El país
#   </a>
#  </li>
#  <li class="p12-separator--right--primary">
#   <a href="https://www.pagina12.com.ar/secciones/economia">
#    Economía
#   </a>
#  </li>
#  <li class="p12-separator--right--primary">
#   <a href="https://www.pagina12.com.ar/secciones/sociedad">
#    Sociedad
#   </a>
#  </li>
#  <li class="no-separator-on-1040 p12-separator--right--primary">
#   <a href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">
#    Cultura y Espectáculos
#   </a>
#  </li>
#  <li class="hide-on-1040 p12-separator--right--primary">
#   <a href="https://www.pagina12.com.ar/secciones/deportes">
#    Deportes
#   </a>
#  </li>
#  <li class="hide-on-1040 p12-separator--right--primary">
#   <a href="https://www.pagina12.com.ar/secciones/el-mundo">
#    El mundo
#   </a>
#  </li>
#  <li class="hide-on-1040">
#   <a href="https://www.pagina12.com.ar/secciones/plastica">
#    Plástica
#   </a>
#  </li>
# </ul>
# <div class="right-header-section mobile-menu-section">
#  <div class="search-form">
#   <form action="/buscar" method="GET" target="_top">
#    <input autocomplete="off" class="search-form__query" name="q" placeholder="Buscar..." tabindex="-1" type="text"/>
#    <button type="submit" value="search">
#     <i aria-hidden="true" class="fa fa-search">
#     </i>
#    </button>
#   </form>
#  </div>
# </div>
# <div class="wrapper" id="p12-user-menu">
#  <form action="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.ar" class="submenu-trigger usermenu-icon" method="post">
#   <input name="redirect" type="hidden" value="https://www.pagina12.com.ar"/>
#   <input name="client" type="hidden" value="hnCJNxS2l9"/>
#   <button role="button" tabindex="1">
#    <i aria-hidden="true" class="fa fa-user">
#    </i>
#   </button>
#  </form>
# </div>
# <div class="page-wrapper">
#  <div class="newsletter" id="newsletter-p12-fullWidth">
#   <div class="newsletter-inner wrapper">
#    <span class="newsletter-close fonticon-close" id="newsletter-close" onclick="dataLayer.push({ 'event':'newsletter-top', 'eventAction':'close' })">
#    </span>
#    <div class="xsmall-12 medium-4 large-6 newsletter-info">
#     <div class="newsletter-title">
#      NEWSLETTER
#     </div>
#     <div class="newsletter-desc">
#      <div class="newsletter-desc-inner" id="newsletter-p12-fullWidth-txt">
#      </div>
#     </div>
#     <div class="newsletter-icon">
#      <img src="https://www.pagina12.com.ar/assets/media/assets/newsletter_img.png"/>
#     </div>
#    </div>
#    <div class="xsmall-12 medium-8 large-6 newsletter-form">
#     <form action="/newsletter-subscribe" id="newsletter-form" method="POST">
#      <div id="newsletter-form-elements">
#       <button id="newsletter-p12-fullWidth-btnTxt" onclick="dataLayer.push({ 'event':'newsletter-top', 'eventAction':'click subscribe btn' })" type="submit">
#       </button>
#       <div class="newsletter-input">
#        <input autocomplete="on" id="email_address" name="email_address" placeholder="Ingresá tu email" type="text"/>
#       </div>
#      </div>
#      <div class="g-recaptcha" data-sitekey="6Ldm2zQUAAAAAE-LWT-VH3OQlNEb6pUbaUF4oZak" id="newsletter-recaptcha" style="">
#      </div>
#      <div id="newsletter-loading">
#       <img src="https://www.pagina12.com.ar/assets/media/assets/loading.gif" style="width: 50px;height: 50px;"/>
#      </div>
#      <div id="newsletter-msg">
#      </div>
#     </form>
#    </div>
#   </div>
#  </div>
#  <div class="ventas-full-width" id="ventas-full-width">
#   <div class="ventas-inner wrapper">
#    <img class="ventas-close" id="ventas-close" onclick="dataLayer.push({ 'event':'ventas-top', 'eventAction':'close' })" src="https://www.pagina12.com.ar/assets/media/assets/close-icon.png"/>
#    <div class="xsmall-12 ventas-info">
#     <div class="ventas-logo" data-src="https://www.pagina12.com.ar" id="ventas-logo">
#     </div>
#     <div class="ventas-slogan" id="ventas-slogan">
#     </div>
#     <div class="ventas-btn">
#      <a data-src="https://www.pagina12.com.ar" href="#" id="ventas-btn" onclick="dataLayer.push({ 'event':'ventas-top', 'eventAction':'ir a membresías' })" target="_blank">
#      </a>
#     </div>
#     <div class="ventas-icon" data-src="https://www.pagina12.com.ar" id="ventas-icon">
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="home">
#   <div class="row">
#    <div class="main-wrapper" id="main-wrapper">
#     <div class="wrapper">
#      <div class="layout-region region-1 moderna">
#       <div class="headlines-group">
#        <div class="columns small-12 medium-6 medium-push-3">
#         <div class="headline-card headline-featured-1 moderna">
#          <article>
#           <div class="column reverse">
#            <div class="rows xsmall-12 medium-12">
#             <div class="headline-content">
#              <div class="article-title">
#               <a href="https://www.pagina12.com.ar/298736-clases-presenciales-en-caba-el-gobierno-porteno-aun-no-infor">
#                <div class="element title-prefix">
#                 La Dirección General de Escuelas sólo confirmó, para esta semana, el inicio de actividades en doce colegios
#                </div>
#                <div class="element title">
#                 Clases presenciales en CABA: el gobierno porteño aún no informó a los docentes cómo implementará la vuelta a las aulas
#                </div>
#                <div class="element title-suffix">
#                 Este lunes, Soledad Acuña anunció la vuelta a la presencialidad, en modalidad "burbuja" y en grupos de a diez chicos, que comenzará el martes para las escuelas técnicas y secundarias. Sin embargo, lo que comunicó la ministra al público no fue especificado a los supervisores ni a los docentes, que no saben con certeza de qué modo volverán los chicos a las escuelas.
#                </div>
#               </a>
#              </div>
#              <div class="time-author-wrapper article-ta">
#               <span class="article-author">
#                <span>
#                 Por
#                </span>
#                <a class="no-link">
#                 Karina Micheletto
#                </a>
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="rows xsmall-12 medium-12">
#             <div class="multimedia-container">
#              <a href="https://www.pagina12.com.ar/298736-clases-presenciales-en-caba-el-gobierno-porteno-aun-no-infor">
#               <div class="intrinsic-container">
#                <img alt='Los chicos del Bajo Flores convocados a la "prueba piloto" son los que comenzarán primero el retorno. ' class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112610-6-a-telam.jpg?itok=FqPqVK9p"/>
#                <img alt='Los chicos del Bajo Flores convocados a la "prueba piloto" son los que comenzarán primero el retorno. ' class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112610-6-a-telam.jpg?itok=mH8Pl60T"/>
#                <img alt='Los chicos del Bajo Flores convocados a la "prueba piloto" son los que comenzarán primero el retorno. ' class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112610-6-a-telam.jpg?itok=mH8Pl60T"/>
#                <img alt='Los chicos del Bajo Flores convocados a la "prueba piloto" son los que comenzarán primero el retorno. ' class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/112610-6-a-telam.jpg?itok=6eEh5_gE"/>
#                <img alt='Los chicos del Bajo Flores convocados a la "prueba piloto" son los que comenzarán primero el retorno. ' class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112610-6-a-telam.jpg?itok=mH8Pl60T"/>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#          </article>
#         </div>
#        </div>
#        <div class="columns small-12 medium-3 medium-pull-6">
#         <div class="row headline-featured-1 white-bg moderna decorated opinion">
#          <div class="headline-card headline-1 decorated opinion">
#           <article class="headline-card-inner">
#            <div class="block-multimedia">
#             <div class="multimedia-container">
#              <a href="https://www.pagina12.com.ar/298718-querido-mempo">
#               <div class="intrinsic-container">
#                <img alt="" class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112594-whatsapp-20image-202020-10-12-20at-2020-29-12.jpeg?itok=qq18t_gE"/>
#                <img alt="" class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112594-whatsapp-20image-202020-10-12-20at-2020-29-12.jpeg?itok=TALo8HQJ"/>
#                <img alt="" class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112594-whatsapp-20image-202020-10-12-20at-2020-29-12.jpeg?itok=qq18t_gE"/>
#                <img alt="" class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/112594-whatsapp-20image-202020-10-12-20at-2020-29-12.jpeg?itok=3pP-vbau"/>
#                <img alt="" class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112594-whatsapp-20image-202020-10-12-20at-2020-29-12.jpeg?itok=qq18t_gE"/>
#               </div>
#              </a>
#             </div>
#            </div>
#            <div class="block-content">
#             <div class="headline-content">
#              <div class="article-title">
#               <a class="title-prefix" href="https://www.pagina12.com.ar/opinion">
#                Opinión
#               </a>
#               <span class="title-separator">
#               </span>
#               <a class="title" href="https://www.pagina12.com.ar/298718-querido-mempo">
#                Querido Mempo
#               </a>
#              </div>
#             </div>
#            </div>
#           </article>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
# <div class="time-author-wrapper article-ta">
#  <span class="article-author">
#   <span>
#    Por
#   </span>
#   <a class="no-link">
#    Alejandro Grimson
#   </a>
#  </span>
# </div>
# <div class="row headline-featured-1 white-bg moderna decorated opinion">
#  <div class="headline-card headline-1 decorated opinion">
#   <article class="headline-card-inner">
#    <div class="block-multimedia">
#     <div class="multimedia-container">
#      <a href="https://www.pagina12.com.ar/298525-al-companero-presidente">
#       <div class="intrinsic-container">
#        <img alt="" class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112376-al-20compa-c3-b1erp-20presidente.jpeg?itok=aYaOChv6"/>
#        <img alt="" class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112376-al-20compa-c3-b1erp-20presidente.jpeg?itok=fduXRxFk"/>
#        <img alt="" class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112376-al-20compa-c3-b1erp-20presidente.jpeg?itok=aYaOChv6"/>
#        <img alt="" class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/112376-al-20compa-c3-b1erp-20presidente.jpeg?itok=Gi-0BQfo"/>
#        <img alt="" class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112376-al-20compa-c3-b1erp-20presidente.jpeg?itok=aYaOChv6"/>
#       </div>
#      </a>
#     </div>
#    </div>
#    <div class="block-content">
#     <div class="headline-content">
#      <div class="article-title">
#       <a class="title-prefix" href="https://www.pagina12.com.ar/opinion">
#        Opinión
#       </a>
#       <span class="title-separator">
#       </span>
#       <a class="title" href="https://www.pagina12.com.ar/298525-al-companero-presidente">
#        Al compañero Presidente
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </div>
# </div>
# <div class="time-author-wrapper article-ta">
#  <span class="article-author">
#   <span>
#    Por
#   </span>
#   <a class="no-link">
#    Mempo Giardinelli
#   </a>
#  </span>
# </div>
# <div class="columns small-12 medium-3">
#  <div class="row headline-featured-1 white-bg moderna">
#   <div class="headline-card headline-1">
#    <article class="headline-card-inner">
#     <div class="block-multimedia">
#      <div class="multimedia-container">
#       <a href="https://www.pagina12.com.ar/298714-amia-una-critica-demoledora-de-la-cidh">
#        <div class="intrinsic-container">
#         <img alt="El informe de la CIDH es lapidario sobre la investigación del atentado a la AMIA." class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112143-13-a-telam.jpg?itok=9RfRv1-0"/>
#         <img alt="El informe de la CIDH es lapidario sobre la investigación del atentado a la AMIA." class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112143-13-a-telam.jpg?itok=Ep2o8w5x"/>
#         <img alt="El informe de la CIDH es lapidario sobre la investigación del atentado a la AMIA." class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112143-13-a-telam.jpg?itok=9RfRv1-0"/>
#         <img alt="El informe de la CIDH es lapidario sobre la investigación del atentado a la AMIA." class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/112143-13-a-telam.jpg?itok=l4eW_c30"/>
#         <img alt="El informe de la CIDH es lapidario sobre la investigación del atentado a la AMIA." class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112143-13-a-telam.jpg?itok=9RfRv1-0"/>
#        </div>
#       </a>
#      </div>
#     </div>
#     <div class="block-content">
#      <div class="headline-content">
#       <div class="article-title">
#        <a "="" href="https://www.pagina12.com.ar/298714-amia-una-critica-demoledora-de-la-cidh">
#         AMIA: Una crítica demoledora de la
#         <span class="title-separator">
#          CIDH
#         </span>
#         <span class="title-prefix">
#          El lapidario informe sobre las falencias de la investigación del atentado en 1994
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </article>
#   </div>
#  </div>
# </div>
# <div class="time-author-wrapper article-ta">
#  <span class="article-author">
#   <span>
#    Por
#   </span>
#   <a class="no-link">
#    Raúl Kollmann
#   </a>
#  </span>
# </div>
# <div class="row headline-featured-1 white-bg moderna">
#  <div class="headline-card headline-1">
#   <article class="headline-card-inner">
#    <div class="block-multimedia">
#     <div class="multimedia-container">
#      <a href="https://www.pagina12.com.ar/298733-mauricio-macri-critico-las-medidas-sanitarias-para-hacerle-f">
#       <div class="intrinsic-container">
#        <img alt="" class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112612-whatsapp-20image-202020-10-12-20at-2022-08-11.jpeg?itok=orfibetF"/>
#        <img alt="" class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112612-whatsapp-20image-202020-10-12-20at-2022-08-11.jpeg?itok=XLdds-7X"/>
#        <img alt="" class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112612-whatsapp-20image-202020-10-12-20at-2022-08-11.jpeg?itok=orfibetF"/>
#        <img alt="" class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/112612-whatsapp-20image-202020-10-12-20at-2022-08-11.jpeg?itok=1Q--dSBJ"/>
#        <img alt="" class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112612-whatsapp-20image-202020-10-12-20at-2022-08-11.jpeg?itok=orfibetF"/>
#       </div>
#      </a>
#     </div>
#    </div>
#    <div class="block-content">
#     <div class="headline-content">
#      <div class="article-title">
#       <a "="" href="https://www.pagina12.com.ar/298733-mauricio-macri-critico-las-medidas-sanitarias-para-hacerle-f">
#        Mauricio Macri criticó las medidas sanitarias para hacerle frente al
#        <span class="title-separator">
#         coronavirus
#        </span>
#        <span class="title-prefix">
#         El exmandatario dijo que "su gobierno" había terminado en agosto de 2019, aunque aún faltaban dos meses para las elecciones
#        </span>
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </div>
# </div>
# <div class="time-author-wrapper article-ta">
# </div>
# <div class="layout-region region-1 moderna">
#  <div class="headlines-group">
#   <div class="row headlines-block white-bg">
#    <div class="columns small-12 medium-3">
#     <div class="headline-card headline-1">
#      <article class="headline-card-inner">
#       <div class="block-multimedia">
#        <div class="multimedia-container">
#         <a href="https://www.pagina12.com.ar/298610-la-ciudad-ilumina-edificios-y-monumentos-con-los-colores-de-">
#          <div class="intrinsic-container">
#           <img alt="" class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112420-cc_0.jpg?itok=8eDba9yx"/>
#           <img alt="" class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112420-cc_0.jpg?itok=-xx76pI9"/>
#           <img alt="" class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112420-cc_0.jpg?itok=8eDba9yx"/>
#           <img alt="" class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/112420-cc_0.jpg?itok=Gz_eQNAV"/>
#           <img alt="" class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112420-cc_0.jpg?itok=8eDba9yx"/>
#          </div>
#         </a>
#        </div>
#       </div>
#       <div class="block-content">
#        <div class="headline-content">
#         <div class="article-title">
#          <a "="" href="https://www.pagina12.com.ar/298610-la-ciudad-ilumina-edificios-y-monumentos-con-los-colores-de-">
#           La Ciudad ilumina edificios y monumentos con los colores de la bandera
#           <span class="title-separator">
#            española
#           </span>
#           <span class="title-prefix">
#            La adhesión del gobierno porteño a la postura española del  descubrimiento de América
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </article>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
# <div class="time-author-wrapper article-ta">
# </div>
# <div class="columns small-12 medium-3">
#  <div class="headline-card headline-1">
#   <article class="headline-card-inner">
#    <div class="block-multimedia">
#     <div class="multimedia-container">
#      <a href="https://www.pagina12.com.ar/298697-coronavirus-en-argentina-se-registraron-318-muertos-y-9-524-">
#       <div class="intrinsic-container">
#        <img alt="" class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/rest_images/para-portada_0.jpeg?itok=TcuaoX3S"/>
#        <img alt="" class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/rest_images/para-portada_0.jpeg?itok=MVRKQ7uk"/>
#        <img alt="" class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/rest_images/para-portada_0.jpeg?itok=TcuaoX3S"/>
#        <img alt="" class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/rest_images/para-portada_0.jpeg?itok=v6WCujkY"/>
#        <img alt="" class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/rest_images/para-portada_0.jpeg?itok=TcuaoX3S"/>
#       </div>
#      </a>
#     </div>
#    </div>
#    <div class="block-content">
#     <div class="headline-content">
#      <div class="article-title">
#       <a "="" href="https://www.pagina12.com.ar/298697-coronavirus-en-argentina-se-registraron-318-muertos-y-9-524-">
#        Coronavirus: Argentina superó los 900.000
#        <span class="title-separator">
#         infectados
#        </span>
#        <span class="title-prefix">
#         Se reportaron 318 muertes por coronavirus en las últimas 24 horas
#        </span>
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </div>
# </div>
# <div class="time-author-wrapper article-ta">
# </div>
# <div class="columns small-12 medium-3">
#  <div class="headline-card headline-1">
#   <article class="headline-card-inner">
#    <div class="block-multimedia">
#     <div class="multimedia-container">
#      <a href="https://www.pagina12.com.ar/298658-marcha-contra-el-gobierno-quiero-que-me-digan-gorila">
#       <div class="intrinsic-container">
#        <img alt="" class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/rest_images/globo_1.jpg?itok=Nga-lw-o"/>
#        <img alt="" class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/rest_images/globo_1.jpg?itok=m85vALNZ"/>
#        <img alt="" class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/rest_images/globo_1.jpg?itok=Nga-lw-o"/>
#        <img alt="" class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/rest_images/globo_1.jpg?itok=KxAioia7"/>
#        <img alt="" class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/rest_images/globo_1.jpg?itok=Nga-lw-o"/>
#       </div>
#      </a>
#     </div>
#    </div>
#    <div class="block-content">
#     <div class="headline-content">
#      <div class="article-title">
#       <a "="" href="https://www.pagina12.com.ar/298658-marcha-contra-el-gobierno-quiero-que-me-digan-gorila">
#        Nueva marcha contra el gobierno, viejas
#        <span class="title-separator">
#         consignas
#        </span>
#        <span class="title-prefix">
#         En el banderazo frente al Obelisco, los manifestantes anticuarentena cantaron a favor de Juntos por el Cambio
#        </span>
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </div>
# </div>
# <div class="time-author-wrapper article-ta">
# </div>
# <div class="columns small-12 medium-3">
#  <div class="headline-card headline-1">
#   <article class="headline-card-inner">
#    <div class="block-multimedia">
#     <div class="multimedia-container">
#      <a href="https://www.pagina12.com.ar/298716-nodio-por-que-se-opone-juntos-por-el-cambio">
#       <div class="intrinsic-container">
#        <img alt='"Hay preocupación por la circulación de mensajes cargados de violencia y desinformación en redes sociales y en medios”, fundamentó la Defensora del Público, Miriam Lewin.' class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112580-lewin.jpg?itok=WCE6ZgCT"/>
#        <img alt='"Hay preocupación por la circulación de mensajes cargados de violencia y desinformación en redes sociales y en medios”, fundamentó la Defensora del Público, Miriam Lewin.' class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112580-lewin.jpg?itok=XOmzO7Xm"/>
#        <img alt='"Hay preocupación por la circulación de mensajes cargados de violencia y desinformación en redes sociales y en medios”, fundamentó la Defensora del Público, Miriam Lewin.' class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112580-lewin.jpg?itok=WCE6ZgCT"/>
#        <img alt='"Hay preocupación por la circulación de mensajes cargados de violencia y desinformación en redes sociales y en medios”, fundamentó la Defensora del Público, Miriam Lewin.' class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/112580-lewin.jpg?itok=QOm3HraV"/>
#        <img alt='"Hay preocupación por la circulación de mensajes cargados de violencia y desinformación en redes sociales y en medios”, fundamentó la Defensora del Público, Miriam Lewin.' class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112580-lewin.jpg?itok=WCE6ZgCT"/>
#       </div>
#      </a>
#     </div>
#    </div>
#    <div class="block-content">
#     <div class="headline-content">
#      <div class="article-title">
#       <a "="" href="https://www.pagina12.com.ar/298716-nodio-por-que-se-opone-juntos-por-el-cambio">
#        Nodio: ¿por qué se opone Juntos por el
#        <span class="title-separator">
#         Cambio?
#        </span>
#        <span class="title-prefix">
#         Observatorio de la desinformación y la violencia simbólica en medios y plataformas digitales
#        </span>
#       </a>
#      </div>
#     </div>
#    </div>
#   </article>
#  </div>
# </div>
# <div class="time-author-wrapper article-ta">
#  <span class="article-author">
#   <span>
#    Por
#   </span>
#   <a href="https://www.pagina12.com.ar/autores/1236-sergio-sanchez">
#    Sergio Sánchez
#   </a>
#  </span>
# </div>
# <div class="ad-shopping show-for-large">
#  <div class="text-center ad-margin-top">
#   <div id="div-gpt-ad-1512067138238-0">
#   </div>
#  </div>
# </div>
# <div class="xsmall-12 block-ads hide-for-medium">
#  <div class="text-center iframe-margin-top">
#   <div id="div-gpt-ad-1503943435188-8">
#   </div>
#  </div>
# </div>
# <div class="wrapper">
#  <div class="tema-1">
#   <div class="layout-region tema tradicional">
#    <div class="row headlines-block headline-block-bg">
#     <div class="headline-block-title">
#      <div class="title-bar">
#      </div>
#      <span class="headline-block-bg">
#      </span>
#     </div>
#     <div class="headline-block-inner">
#      <div class="columns small-12 medium-3">
#       <div class="headline-card headline-1">
#        <article class="headline-card-inner">
#         <div class="block-multimedia">
#          <div class="multimedia-container">
#           <a href="https://www.pagina12.com.ar/298713-protestas-anticuarentena-en-la-casa-de-cristina-kirchner">
#            <div class="intrinsic-container">
#             <img alt="" class="show-for-small-only lazyload" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112435-whatsapp-20image-202020-10-12-20at-2020-34-27.jpeg?itok=H5rTNCvc" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247"/>
#             <img alt="" class="show-for-medium-only lazyload" data-src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112435-whatsapp-20image-202020-10-12-20at-2020-34-27.jpeg?itok=i24WxpRd" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247"/>
#             <img alt="" class="show-for-large-only lazyload" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112435-whatsapp-20image-202020-10-12-20at-2020-34-27.jpeg?itok=H5rTNCvc" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247"/>
#             <img alt="" class="show-for-xsmall-only lazyload" data-src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/112435-whatsapp-20image-202020-10-12-20at-2020-34-27.jpeg?itok=aqBQZQxO" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247"/>
#             <img alt="" class="show-for-xlarge lazyload" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112435-whatsapp-20image-202020-10-12-20at-2020-34-27.jpeg?itok=H5rTNCvc" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247"/>
#            </div>
#           </a>
#          </div>
#         </div>
#         <div class="block-content">
#          <div class="headline-content">
#           <div class="article-title">
#            <a "="" href="https://www.pagina12.com.ar/298713-protestas-anticuarentena-en-la-casa-de-cristina-kirchner">
#             Protestas anticuarentena en la casa de Cristina
#             <span class="title-separator">
#              Kirchner
#             </span>
#             <span class="title-prefix">
#              Amplio repudio del oficialismo a la convocatoria frente al domicilio de la vicepresidenta
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#        </article>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
# <div class="time-author-wrapper article-ta">
#  <span class="article-author">
#   <span>
#    Por
#   </span>
#   <a class="no-link">
#    Werner Pertot
#   </a>
#  </span>
# </div>
# <div class="columns small-12 medium-3">
#  <div class="headline-card headline-1">
#   <article class="headline-card-inner">
#    <div class="block-multimedia">
#     <div class="multimedia-container">
#      <a href="https://www.pagina12.com.ar/298631-el-coronavirus-puede-sobrevivir-hasta-28-dias-en-billetes-o-">
#       <div class="intrinsic-container">
#        <img alt="" class="show-for-small-only lazyload" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112426-whatsapp-20image-202020-10-12-20at-2014-13-41.jpeg?itok=IwawE7tF" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247"/>
#        <img alt="" class="show-for-medium-only lazyload" data-src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/112426-whatsapp-20image-202020-10-12-20at-2014-13-41.jpeg?itok=oSNyWnjZ" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247"/>
#        <img alt="" class="show-for-large-only lazyload" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/112426-whatsapp-20image-202020-10-12-20at-2014-13-41.jpeg?itok=IwawE7tF" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.247"/>
# ...
# </div>
# <div class="footer black-bg">
#  <div class="footer-content row" id="footer">
#   <div class="wrapper">
#    <div class="row">
#     <div class="large-12 column logos">
#      <div class="large-4 medium-4 small-12 columns social-media hide-for-xsmall-only hide-for-small-only">
#       <ul>
#        <li>
#         <a href="https://www.facebook.com/Pagina12ok/" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/facebook-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://twitter.com/pagina12" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/twitter-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.instagram.com/pagina12/" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/instagram-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/youtube-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://t.me/pagina12" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/telegram-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="large-4 medium-4 small-12 columns header-image">
#       <a href="https://www.pagina12.com.ar">
#        <img src="https://www.pagina12.com.ar/assets/media/assets/Pagina12-Logo-footer_blanco.svg?v=1.0.247"/>
#       </a>
#      </div>
#      <div class="large-4 medium-4 small-12 columns social-media show-for-xsmall hide-for-medium">
#       <ul>
#        <li>
#         <a href="https://www.facebook.com/Pagina12ok/" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/facebook-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://twitter.com/pagina12" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/twitter-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.instagram.com/pagina12/" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/instagram-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/youtube-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://t.me/pagina12" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/social/telegram-white.svg?v=1.0.247"/>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="large-4 medium-4 hide-for-xsmall-only hide-for-small-only columns group">
#       <a href="http://octubre.com" target="_blank">
#        <img src="https://www.pagina12.com.ar/assets/media/assets/Logo-octubre-color-footer.svg?v=1.0.247"/>
#       </a>
#      </div>
#     </div>
#     <div class="large-12 column page-map">
#      <div class="row">
#       <div class="column large-12">
#        <div class="row">
#         <div class="columns medium-6 large-6">
#          <div class="row">
#           <div class="columns large-4 medium-4">
#            <h3 class="hide-for-xsmall-only hide-for-small-only">
#             PÁGINA 12
#            </h3>
#            <ul class="one-column-list">
#             <li>
#              <a href="https://www.pagina12.com.ar/pagina/Contacto">
#               Contacto
#              </a>
#             </li>
#            </ul>
#            <div class="rss">
#             <a href="https://www.pagina12.com.ar/pagina/rss">
#              <img class="icon icon--icon-small" src="https://www.pagina12.com.ar/assets/media/assets/icon-rss.svg?v=1.0.247"/>
#              RSS
#             </a>
#            </div>
#           </div>
#           <div class="columns large-8 medium-8 hide-for-xsmall-only hide-for-small-only">
#            <h3>
#             SUPLEMENTOS
#            </h3>
#            <ul class="three-column-list">
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/cash">
#               Cash
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/el-enganche">
#               Enganche
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/radar">
#               Radar
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/turismo">
#               Turismo
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/radar-libros">
#               Radar Libros
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/no">
#               NO
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/soy">
#               Soy
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/las12">
#               Las12
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/universidad">
#               Universidad
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/satira12">
#               Sátira12
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/m2">
#               M2
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/rosario12">
#               Rosario12
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/verano12">
#               Verano12
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/libero">
#               Líbero
#              </a>
#             </li>
#             <li>
#              <a href="https://www.pagina12.com.ar/suplementos/especiales">
#               Especiales de P12
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <div class="columns large-6 medium-6 hide-for-xsmall-only hide-for-small-only">
#          <h3 class="otros">
#           OTRAS PUBLICACIONES
#          </h3>
#          <ul class="three-column-list otros">
#           <li>
#            <a href="http://radioam750.com.ar">
#             AM|750
#            </a>
#           </li>
#           <li>
#            <a href="https://oktubre.fm">
#             Oktubre FM
#            </a>
#           </li>
#           <li>
#            <a href="http://carasycaretas.org.ar">
#             Caras y Caretas
#            </a>
#           </li>
#           <li>
#            <a href="https://salas.carasycaretas.org.ar/">
#             Caras y Caretas Sala
#            </a>
#           </li>
#           <li>
#            <a href="https://octubretv.com/">
#             Octubre TV
#            </a>
#           </li>
#           <li>
#            <a href="http://www.editorialoctubre.com.ar">
#             Editorial Octubre
#            </a>
#           </li>
#           <li>
#            <a href="http://www.diarioz.com.ar">
#             Diario Z
#            </a>
#           </li>
#           <li>
#            <a href="http://elplanetaurbano.com">
#             El Planeta Urbano
#            </a>
#           </li>
#           <li>
#            <a href="https://fmlike.com.ar/">
#             FM Like
#            </a>
#           </li>
#           <li>
#            <a href="http://www.iso.edu.ar">
#             ISO
#            </a>
#           </li>
#           <li>
#            <a href="http://umet.edu.ar">
#             UMET
#            </a>
#           </li>
#           <li>
#            <a href="http://latinoamericapiensa.com">
#             Latinoamérica Piensa
#            </a>
#           </li>
#           <li>
#            <a href="http://radiomalena.com">
#             Malena FM
#            </a>
#           </li>
#           <li>
#            <a href="https://www.elnueve.com.ar/">
#             El Nueve
#            </a>
#           </li>
#           <li>
#            <a href="https://cluboctubre947.com/">
#             Club 947
#            </a>
#           </li>
#           <li>
#            <a href="https://fmaspen.com/">
#             Aspen 102.3
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="show-for-xsmall hide-for-medium small-12 columns">
#        <div class="group">
#         <a href="http://octubre.com" target="_blank">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/Logo-octubre-color-footer.svg?v=1.0.247"/>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="column large-12">
#      <p class="disclaimer">
#       <span>
#        República Argentina
#       </span>
#       <span>
#        |
#       </span>
#       <span>
#        Todos los derechos reservados
#       </span>
#       <span>
#        |
#       </span>
#       <a href="https://www.pagina12.com.ar/pagina/politica-de-privacidad">
#        Política de privacidad
#       </a>
#       <span>
#        |
#       </span>
#       <a href="https://www.pagina12.com.ar/pagina/terminos-y-condiciones">
#        Términos y Condiciones
#       </a>
#       <span>
#        © 2000-2020 www.pagina12.com.ar
#       </span>
#      </p>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
# <div class="no-cookies-js no-cookies" id="no-cookies">
#  <div class="no-cookies-js-inner">
#   Tu navegador tiene deshabilitado el uso de Cookies. Algunas funcionalidades de Página/12 necesitan que lo habilites para funcionar. Si no sabés como hacerlo hacé
#   <a href="http://academia.colnodo.apc.org/pluginfile.php/1608/block_html/content/Habilitar%20Cookies.pdf" target="_blank">
#    CLICK AQUÍ
#   </a>
#   <div class="fonticon-close" id="no-cookies-close">
#   </div>
#  </div>
# </div>
# <noscript>
#  <div class="no-cookies-js" id="no-js">
#   <div class="no-cookies-js-inner">
#    Tu navegador tiene deshabilitado el uso de Javascript. Muchas de las funcionalidades de Página/12 necesitan que lo habilites para funcionar. Si no sabés como hacerlo hacé
#    <a href="https://enable-javascript.com/es" target="_blank">
#     CLICK AQUÍ
#    </a>
#   </div>
#  </div>
# </noscript>
# <script type="text/javascript">
#  (function() {function checkCookie() {/* Quick test if browser has cookieEnabled host property */if (navigator.cookieEnabled) return true;/* Create cookie */document.cookie = "cookietest=1";var ret = document.cookie.indexOf("cookietest=") != -1;/* Delete cookie */document.cookie = "cookietest=1; expires=Thu, 01-Jan-1970 00:00:01 GMT";return ret;}if(!checkCookie()) {var noCookies = document.getElementById('no-cookies');noCookies.style.display = 'block';var noCookiesClose = document.getElementById('no-cookies-close');noCookiesClose.addEventListener('click', function () {noCookies.style.display = 'none';})}})();
# </script>
# <!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js"></script><![endif]-->
# <script src="https://www.pagina12.com.ar/assets/js/vendor/vendor.min.js?v=1.0.247" type="text/javascript">
# </script>
# <script src="https://www.pagina12.com.ar/assets/js/main.min.js?v=1.0.247" type="text/javascript">
# </script>
# <script type="text/javascript">
#  $.fn.isInViewport = function() {var elementTop = $(this).offset().top;var elementBottom = elementTop + $(this).outerHeight();var viewportTop = $(window).scrollTop();var viewportBottom = viewportTop + $(window).height();return elementBottom > viewportTop && elementTop < viewportBottom;};
# </script>
# <script class="jwplayer-script">
# </script>
# <script type="text/javascript">
#  let playing = false;let youtubePlayers = [];function onIframelyReady(e) {const iframely = window.iframely;iframely && iframely.on('iframe-ready', iframe => {handleIframelyVideos(iframe);});}function handleIframelyVideos(iframe) {if (!playerjs) console.warn('Player.js is not enabled');const player = new playerjs.Player(iframe);player.supports('event', 'play') && player.on('play', onVideoPlay);player.supports('event', 'pause') && player.on('pause', onVideoStop);player.supports('event', 'ended') && player.on('ended', onVideoStop);}function onYouTubeIframeAPIReady() {$youtubeEmbeds = $('.article-youtube-embed');$youtubeEmbeds.each(function(_, youtubeEmbed) {const embedId = $(this).attr('id');createYouTubePlayer(embedId);});}function createYouTubePlayer(playerId) {const newPlayer = new YT.Player(playerId, {events: {'onStateChange': onPlayerStateChange}});youtubePlayers.push(newPlayer);}function onPlayerStateChange(event) {playing = youtubePlayers.some((player) => {return player.getPlayerState() === YT.PlayerState.PLAYING;});if (event.data === YT.PlayerState.PLAYING) {onVideoPlay();}if (event.data === YT.PlayerState.PAUSED || event.data === YT.PlayerState.ENDED) {if (!playing) onVideoStop();}}function onVideoPlay() {if (window.reloadPage) {clearInterval(window.reloadPage.timer);window.reloadPage.counter = '5';}}function onVideoStop() {reloadHandler('5')}function reloadHandler(delay) {/*** Refresh common functions (Mobile and Desktop).*/const isMobile = function() {return (navigator.userAgent.match(/(iPad|iPhone)/i) != null || navigator.userAgent.match(/Android/i) != null);};const onEvent = function() {window.location.reload(true);};/*** Refresh functions for Desktop.*/const timerFn = function() {return setInterval(function(t) {if (userHasWrittenAComment()) {return clearInterval(window.reloadPage.timer);}window.reloadPage.counter--;console.log('Reload timeout:', window.reloadPage.counter, 'minutes');if (window.reloadPage.counter <= 0) {onEvent();}}, 60000);};/*** Returns True if the user has written a Talk comment.** Talk saves the comment in the sessionStorage so, in order* to know whether the user has written a comment, we need* to check if talkPymStorage:DraftArea_comment-draft_xxx* has a value.*/const userHasWrittenAComment = function() {const storageKeys = Object.keys(window.sessionStorage || {});return storageKeys.some((storageKey) => {const userHasCommented = /^talkPymStorage:DraftArea_comment-draft_.*/.test(storageKey);if (userHasCommented) {const commentData = window.sessionStorage.getItem(storageKey);const comment = JSON.parse(commentData || '{}');return comment.body ? comment.body.length > 0 : false;}return false;});};const manageEvent = function(e) {if (window.reloadPage.timer) {window.reloadPage.counter = delay;}};const manageMessageEvent = function(e) {const evntData = {};try {evntData = JSON.parse(e.originalEvent.data);} catch (err) { }if (evntData.channel) {manageEvent(e);}};const initRefreshForDesktop = function() {window.reloadPage = {timer: null,counter: delay};const eventList = ['resize','scroll','touchmove'];if (eventList && eventList.length > 0) {eventList.forEach(function(evt) {$(window).on(evt, manageEvent);});}$('.video-embed-field-responsive-video').on('mouseenter', () => clearInterval(window.reloadPage.timer));$('.video-embed-field-responsive-video').on('mouseleave', () => { window.reloadPage.timer = timerFn(); });$(window).on('message', manageMessageEvent);$('video').on('timeupdate', manageEvent);window.reloadPage.timer = timerFn();};/*** Refresh functions for Mobile.*/let lastTimePageWasInactive = undefined;const getHiddenPropertyFromPrefix = function(prefix) {return prefix ? (prefix + 'Hidden') : 'hidden';};const getVisibilityChangeFromPrefix = function(prefix) {return (prefix || '') + 'visibilitychange';};const getPrefix = function() {const browserPrefixes = ['moz', 'ms', 'o', 'webkit'];for (let index = 0; index < browserPrefixes.length; index++) {const prefix = browserPrefixes[index];if (getHiddenProp ...
# </script>
# <script data-cf-beacon='{"rayId":"5e1624c8bc6d7f80","version":"2020.9.1","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js">
# </script>
